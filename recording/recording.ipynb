# %%
import os
import hashlib
import numpy as np
import soundfile as sf
from numpy.random import randint


class SampleSaver:
    def __init__(self, sample_rate, folder_name="datasets/HeyPiSamples"):
        self.sample_rate = sample_rate
        self.folder = folder_name
        self.files_count = 0

        if not os.path.exists(self.folder):
            os.makedirs(self.folder)
            print(f"Created folder: {self.folder}")
        else:
             self.files_count = sum(1 for entry in os.scandir(folder_name) if entry.is_file())

    def save(self, audio: np.ndarray):
        if len(audio) == 0:
            print("Audio buffer is empty, nothing to save.")
            return None
        audio = audio.astype(np.float32)
        hash_str = hashlib.md5(audio.tobytes()).hexdigest()
        filepath = os.path.join(self.folder, f"hey_pi_{hash_str}.wav")
        sf.write(filepath, audio, self.sample_rate)

        print(f"Saved: {filepath}\t total files count: {self.files_count}")
        self.files_count += 1
        return filepath

sample_saver = SampleSaver(16000)

# %%
import sounddevice as sd
import numpy as np
import queue
import librosa
import time
import threading
from random import randint

SAMPLE_RATE = 16000
WINDOW_SIZE = 1.0

WINDOW_SAMPLES = int(SAMPLE_RATE * WINDOW_SIZE)

audio_queue = queue.Queue()
audio_buffer = np.array([], dtype=np.float32)


def callback(indata, frames, time, status):
    if status:
        print(status)
    audio_queue.put(indata.copy().flatten())

word_detected_flag = False

with sd.InputStream(channels=1, callback=callback) as stream:
    sr = stream.samplerate
    print("Actual mic sample rate:", sr)
    try:
        while True: 
            new_audio = librosa.resample(audio_queue.get(), orig_sr=int(sr), target_sr=SAMPLE_RATE)
            if new_audio is None:
                continue
            if not word_detected_flag and len(audio_buffer) >= WINDOW_SAMPLES:
                avg_loughtness = np.mean(np.abs(audio_buffer))
                new_audio_loughtness = np.mean(np.abs(new_audio))
                if (avg_loughtness * 20 < new_audio_loughtness):
                        print("Word Detected")
                        word_detected_flag = True
                        audio_buffer = audio_buffer[-min(len(audio_buffer),randint(0,WINDOW_SAMPLES//4)):] #Randomly cut previous buffer before word 
            else:
                if (len(audio_buffer) >= WINDOW_SAMPLES):
                    word_audio = audio_buffer[:WINDOW_SAMPLES]
                    sd.play(word_audio, SAMPLE_RATE)
                    sample_saver.save(word_audio)
                    word_detected_flag = False
            audio_buffer = np.concatenate((audio_buffer, new_audio))
            if len(audio_buffer) >= WINDOW_SAMPLES * 2:
                audio_buffer = audio_buffer[WINDOW_SAMPLES:]
    except KeyboardInterrupt:
        print("Exiting from keyboard interrupt")
# Out:
# Actual mic sample rate: 44100.0
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_4796312d121bda989f9313724bdb3a99.wav	 total files count: 97
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_13983b078d56724c76eef51237d1e0d6.wav	 total files count: 98
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_7ba6ca7dbe99e95d72a9c840d01e2a76.wav	 total files count: 99
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_17b3a6bc98870460f9e0f41c8243f73e.wav	 total files count: 100
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_9e77de9941550b0c636128db33f64cda.wav	 total files count: 101
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_8e2794cd2efcd9ed2e97ed7683f64c05.wav	 total files count: 102
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_042f6c45d7703f3589e5225788df78bd.wav	 total files count: 103
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_5ab2aafbfa32b81304149e8b26ca7423.wav	 total files count: 104
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_159a0a737ebc56cf2d3c2eb8b8039deb.wav	 total files count: 105
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_db5cec17c6e9bf0426daf6c6523d2a76.wav	 total files count: 106
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_a486b7b4b0e34fdb43a68494bc9d6354.wav	 total files count: 107
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_f8d289765b966431747d4f05d2117293.wav	 total files count: 108
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_69443d89bc74fdc951972932af634588.wav	 total files count: 109
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_75f141adce16c373ded6b5a151bda07c.wav	 total files count: 110
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_f41d707261f9138c5273d3eb0639da21.wav	 total files count: 111
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_b1e9874480acf1c1400f7027cd587cb1.wav	 total files count: 112
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_ef9fbaa487120a429b7effd72cfa2475.wav	 total files count: 113
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_04a4cf335762a1b1917b50fc5d74f8b1.wav	 total files count: 114
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_0035692586b21dccae5b06a82bdd14b7.wav	 total files count: 115
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_0d8c9d72696a62418aceef643489112d.wav	 total files count: 116
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_7b97811b42f59bed24728228dc6bfa02.wav	 total files count: 117
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_243e737e85820ea714f4bcb1f2697291.wav	 total files count: 118
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_bed5c26dfd5afa06a4e81e185ce03858.wav	 total files count: 119
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_5d297eacabc2bbac250ea7180df63585.wav	 total files count: 120
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_8dda3712a00e4ed5c9f1c8ca49cb3b27.wav	 total files count: 121
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_1aa1c0d6476c3d63833c43529529d391.wav	 total files count: 122
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_56ac9b01abbe3437424213f419642077.wav	 total files count: 123
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_11a5c66d1018858898da7285f10372a1.wav	 total files count: 124
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_8188f9bf2ed4ae2ff45498d8aa3bcb2c.wav	 total files count: 125
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_b972c9f72c268fe7265f46561dc834f1.wav	 total files count: 126
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_fd2f133c0e928ffcbf49a4c3c5124582.wav	 total files count: 127
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_6c8da0b3f9ba543bb5afbe95f879d541.wav	 total files count: 128
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_463cec221e8faa4c04082627cde0cc89.wav	 total files count: 129
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_d72853049a4f66400eb1025c05fb1c67.wav	 total files count: 130
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_6b101f1bf96605514fe1a9733371d1b5.wav	 total files count: 131
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_219338ad601e936731bab8e67dde58a0.wav	 total files count: 132
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_a1a6c9238dc170ed1e850ec438807438.wav	 total files count: 133
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_c17ee4c538ab294593415f69328b818d.wav	 total files count: 134
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_43b310517cf15638f298947741f8f044.wav	 total files count: 135
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_1c4770b7b0784b64e389b808e7cf726d.wav	 total files count: 136
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_f5777fa099ffc1b5d64cbfd2e0aea809.wav	 total files count: 137
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_c65ffb67aaea6e562d39754c872251f3.wav	 total files count: 138
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_5813968821fa0500b2ee51ab183cacf7.wav	 total files count: 139
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_25cd8238a2e6fb6ff7c34287b7ff0a06.wav	 total files count: 140
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_2ef22eef95317926165d5f57111c9370.wav	 total files count: 141
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_4668966c0446ea2c1bf3d91eb6ce1c1d.wav	 total files count: 142
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_f90138fc4b5449f48a9e534087c130bc.wav	 total files count: 143
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_8ce3cf282c12e2ca80d54c30d874d78d.wav	 total files count: 144
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_66b4e2e81b1197dbc882bcc7ce4078a4.wav	 total files count: 145
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_306718929b158377cdc0ca14804936b7.wav	 total files count: 146
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_e3f93dfe3659014f0acdd866deaedbf5.wav	 total files count: 147
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_09d4b370c37a57c4c3dfaff89266cf7d.wav	 total files count: 148
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_02c17acbd4519fa6c068ec7483c8e350.wav	 total files count: 149
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_19510d7abb75c3e825c9e8c838068988.wav	 total files count: 150
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_b973e87e786fcca13690bb57e0214ecd.wav	 total files count: 151
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_04be383413504d40bf14ca86a3eb46ff.wav	 total files count: 152
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_a996acd8d48825084ee359706ce848c5.wav	 total files count: 153
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_f37bd17d43f1be00494b544c3a5b6f2f.wav	 total files count: 154
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_7c7351dd08b395b98f5ab7d29df81663.wav	 total files count: 155
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_adb444a9abf5d393f86a85cb2686193a.wav	 total files count: 156
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_d0617795c34ecbcb8d271eae10d1d8a8.wav	 total files count: 157
# Word Detected
# Saved: datasets/HeyPiSamples\hey_pi_65f45d55bac376e776d6e4a622516a6c.wav	 total files count: 158
# Exiting from keyboard interrupt
